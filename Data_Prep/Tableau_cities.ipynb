# %% [markdown]
# # Imports & Read Data

# %%
#Imports
import pandas as pd
import json
import csv

#set disaply precision
# pd.set_option('display.precision', 2)

# %%
#Read the CSV & Create DF
facilities_no_cities = pd.read_csv("Export/tableau_facility_data.csv")
facilities_no_cities
# Out:
#     facility_id                      facility_name  google_lat  google_long  \
# 0     FA0000009    AMERICAN LEGION BOULDER POST 10   40.060591  -105.273595
# 1     FA0000010                MOXIE BREAD COMPANY   39.976717  -105.132303
# 2     FA0000011                         ABOS PIZZA   40.100740  -105.168125
# 3     FA0000015                 MT EVEREST CUISINE   39.998027  -105.232897
# 4     FA0000017    UNDER THE SUN EATERY & TAPHOUSE   39.705197  -104.987561
# ..          ...                                ...         ...          ...
# 861   FA0005449                WHOLE SOL BLEND BAR   40.018204  -105.276692
# 862   FA0005472                 COMA MEXICAN GRILL   39.998027  -105.232897
# 863   FA0005494              ROSATIS CHICAGO PIZZA   39.980325  -105.128412
# 864   FA0005506  SCRATCH (INSIDE 300 SUNS BREWING)   40.159920  -105.101274
# 865   FA0005510             CROSSING NUTRITION THE   39.985591  -105.096899
#
# ...

# %%
#Read cleaned data with city information
facilities_cities = pd.read_csv("Export/unique_restaurants_geocoded.csv")
facilities_cities
# Out:
#      facilityId                          facilityName        siteAddress  \
# 0     FA0003323                                 RUNZA       1743 MAIN ST
# 1     FA0000616                     FRANKS CHOP HOUSE      921 WALNUT ST
# 2     FA0004494                  ROASTED TOAD BBQ THE        229 HWY 119
# 3     FA0003893  FAIR ISLE COFFEE CO @ LGMT FARM MRKT     237 COLLYER ST
# 4     FA0003472                    TODS ESPRESSO CAFE    6558 LOOKOUT RD
# ...         ...                                   ...                ...
# 1072  FA0005279                  VOLCAN AZUL (MOBILE)     600 COFFMAN ST
# 1073  FA0005473           ALTAVITA INDEPENDENT LIVING  1002 ALTA VITA CT
# 1074  FA0005424                        BIG LOTS #4685       2151 MAIN ST
# 1075  FA0005494                 ROSATIS CHICAGO PIZZA   1067 COURTESY RD
# 1076  FA0005326  BOULDER COUNTY AIDS PROJECT (PANTRY)       2118 14TH ST
#
#      streetNumber streetDirection streetName streetType streetUnit  \
# ...

# %% [markdown]
# # Matching Facility ID and adding a field to DB data

# %%
for index, row in facilities_cities.iterrows():
        #find the city, facID, and address
        facID = facilities_cities.loc[index, "facilityId"]
        city = facilities_cities.loc[index, "city"]
        site_add = facilities_cities.loc[index, "siteAddress"]

        #drop the city and site address into the clean dataframe
        facilities_no_cities.loc[(facID == facilities_no_cities["facility_id"]), 'city'] = city
        facilities_no_cities.loc[(facID == facilities_no_cities["facility_id"]), 'siteAddress'] = site_add
              
facilities_no_cities
# Out:
#     facility_id                      facility_name  google_lat  google_long  \
# 0     FA0000009    AMERICAN LEGION BOULDER POST 10   40.060591  -105.273595
# 1     FA0000010                MOXIE BREAD COMPANY   39.976717  -105.132303
# 2     FA0000011                         ABOS PIZZA   40.100740  -105.168125
# 3     FA0000015                 MT EVEREST CUISINE   39.998027  -105.232897
# 4     FA0000017    UNDER THE SUN EATERY & TAPHOUSE   39.705197  -104.987561
# ..          ...                                ...         ...          ...
# 861   FA0005449                WHOLE SOL BLEND BAR   40.018204  -105.276692
# 862   FA0005472                 COMA MEXICAN GRILL   39.998027  -105.232897
# 863   FA0005494              ROSATIS CHICAGO PIZZA   39.980325  -105.128412
# 864   FA0005506  SCRATCH (INSIDE 300 SUNS BREWING)   40.159920  -105.101274
# 865   FA0005510             CROSSING NUTRITION THE   39.985591  -105.096899
#
# ...

# %%
facilities_no_cities.isnull().sum()
# Out:
# facility_id             0
# facility_name           0
# google_lat              0
# google_long             0
# price_level             0
# rating                  0
# total_ratings           0
# avg_inspection_score    0
# avg_violations_count    0
# city                    0
# dtype: int64

# %% [markdown]
# # Export to CSV

# %%
# Export cleaned, final dataset for tableau
output_data = "Export/tableau_facility_data_cities.csv"
facilities_no_cities.to_csv(output_data,header=True,index=False)

# %% [markdown]
# # Cleaned Facility Data to Json for Dashboard

# %%
#Read the CSV & Create DF
facilities = pd.read_csv("Export/tableau_facility_data_cities.csv")
facilities.head(10)
# Out:
#   facility_id                    facility_name  google_lat  google_long  \
# 0   FA0000009  AMERICAN LEGION BOULDER POST 10   40.060591  -105.273595
# 1   FA0000010              MOXIE BREAD COMPANY   39.976717  -105.132303
# 2   FA0000011                       ABOS PIZZA   40.100740  -105.168125
# 3   FA0000015               MT EVEREST CUISINE   39.998027  -105.232897
# 4   FA0000017  UNDER THE SUN EATERY & TAPHOUSE   39.705197  -104.987561
# 5   FA0000018                     DISH GOURMET   40.019705  -105.270186
# 6   FA0000021     ROCKY MOUNTAIN PATHWAY RANCH   40.193437  -105.511216
# 7   FA0000024                 ABOS PIZZA SOUTH   39.705075  -104.987575
# 8   FA0000025                 ABOS PIZZA NORTH   40.037547  -105.259361
# 9   FA0000026                       ABOS PIZZA   39.987999  -105.125530
#
#    price_level  rating  total_ratings  avg_inspection_score  \
# 0            2     4.9             15             36.000000
# ...

# %%
#transform city names to all caps
facilities["city"] = facilities["city"].str.upper()

# %%
# add data to name line for display via website code
facilities['facility_name_plus'] = facilities['city']+' - '+facilities['facility_name']+' - '+facilities['siteAddress']
facilities
# Out:
#     facility_id                      facility_name  google_lat  google_long  \
# 0     FA0000009    AMERICAN LEGION BOULDER POST 10   40.060591  -105.273595
# 1     FA0000010                MOXIE BREAD COMPANY   39.976717  -105.132303
# 2     FA0000011                         ABOS PIZZA   40.100740  -105.168125
# 3     FA0000015                 MT EVEREST CUISINE   39.998027  -105.232897
# 4     FA0000017    UNDER THE SUN EATERY & TAPHOUSE   39.705197  -104.987561
# ..          ...                                ...         ...          ...
# 861   FA0005449                WHOLE SOL BLEND BAR   40.018204  -105.276692
# 862   FA0005472                 COMA MEXICAN GRILL   39.998027  -105.232897
# 863   FA0005494              ROSATIS CHICAGO PIZZA   39.980325  -105.128412
# 864   FA0005506  SCRATCH (INSIDE 300 SUNS BREWING)   40.159920  -105.101274
# 865   FA0005510             CROSSING NUTRITION THE   39.985591  -105.096899
#
# ...

# %%
#sort dataframe by facility & city
facilities = facilities.sort_values(by = ['facility_name_plus', 'city'], axis=0, 
                                              ascending = [True, True])
facilities.tail(30)
# Out:
#     facility_id                      facility_name  google_lat  google_long  \
# 65    FA0000230  TRAIN CARS COFFEE & YOGURT CO THE   39.960384  -105.510129
# 20    FA0000075               TRES GRINGOS CANTINA   39.959823  -105.509431
# 294   FA0000942                  UBON THAI CUISINE   39.964973  -105.503948
# 829   FA0005208     VEGETABLE EXPRESS THE (MOBILE)   39.961376  -105.510831
# 765   FA0004879                         1914 HOUSE   40.103291  -105.172771
# 2     FA0000011                         ABOS PIZZA   40.100740  -105.168125
# 69    FA0000238               FANS CHINESE CUISINE   40.100049  -105.167244
# 88    FA0000314                   GARDEN GATE CAFE   40.100785  -105.168114
# 154   FA0000487            LEFTYS GADGET AND PIZZA   40.102041  -105.170054
# 711   FA0004603                  NIWOT WHEEL WORKS   40.103205  -105.172910
# 376   FA0001240            OLD OAK COFFEEHOUSE THE   40.103381  -105.172179
# ...

# %%
#create facilities DF with data columns
facilities_json = facilities[["city", "facility_name", "facility_name_plus", "facility_id", "rating", "total_ratings", "avg_inspection_score", "avg_violations_count"]]
facilities_json
# Out:
#            city                 facility_name  \
# 160  ALLENSPARK          MEADOW MOUNTAIN CAFE
# 6    ALLENSPARK  ROCKY MOUNTAIN PATHWAY RANCH
# 407     BOULDER           (CU)  FARRAND ALLEY
# 442     BOULDER                (CU) SEEC CAFE
# 408     BOULDER     (CU) SEWALL DINING CENTER
# ..          ...                           ...
# 426    SUPERIOR                  SUSHI OUTLET
# 427    SUPERIOR             TEQUILA Y MEZCHAL
# 90         WARD            GLACIER VIEW RANCH
# 722        WARD        JACKLEGGERS MERCANTILE
# 167        WARD                  MILLSITE INN
#
#                                     facility_name_plus facility_id  rating  \
# 160  ALLENSPARK - MEADOW MOUNTAIN CAFE - 441 BUSINE...   FA0000515     4.7
# 6    ALLENSPARK - ROCKY MOUNTAIN PATHWAY RANCH - 15...   FA0000021     4.9
# 407     BOULDER - (CU)  FARRAND ALLEY - 2200 BARKER DR   FA0001319     4.3
# 442       BOULDER - (CU) SEEC CAFE - 4001 DISCOVERY DR   FA0001542     4.0
# ...

# %% [markdown]
# # Merging Database files with Specific Violation data

# %%
#Read database export containing Violation information
facilities_violations = pd.read_csv("Export/violations_by_facility.csv")
facilities_violations
# Out:
#      facility_id inspection_date          violation_category  \
# 0      FA0000009      2015-04-09         toilets/handwashing
# 1      FA0000009      2017-05-09                 food source
# 2      FA0000009      2017-05-09       water/sewage/plumbing
# 3      FA0000009      2017-05-09         toilets/handwashing
# 4      FA0000009      2017-05-09  equipment/utensil cleaning
# ...          ...             ...                         ...
# 8725   FA0005510      2019-10-14                   personnel
# 8726   FA0005510      2019-10-14                   personnel
# 8727   FA0005534      2019-10-08                 food source
# 8728   FA0005534      2019-10-08                pest control
# 8729   FA0005535      2019-12-13  equipment/utensil cleaning
#
#                                                   lower
# 0                               soap and drying devices
# 1                                   cross contamination
# 2                               backflow back siphonage
# ...

# %%
#sort by descending by most recent violation date
facilities_violations = facilities_violations.sort_values(by = ['inspection_date'], axis=0, 
                                              ascending = False)
facilities_violations
# Out:
#      facility_id inspection_date        violation_category  \
# 5511   FA0001782      2019-12-30               food source
# 5510   FA0001782      2019-12-30       toilets/handwashing
# 5509   FA0001782      2019-12-30                 personnel
# 5508   FA0001782      2019-12-30     water/sewage/plumbing
# 631    FA0000193      2019-12-26               food source
# ...          ...             ...                       ...
# 1205   FA0000356      2013-01-02                 personnel
# 1204   FA0000356      2013-01-02            poisons/toxins
# 4660   FA0001272      2013-01-02                 personnel
# 4659   FA0001272      2013-01-02     water/sewage/plumbing
# 7153   FA0003410      2013-01-02  food temperature control
#
#                                                   lower
# 5511                proper date marking and disposition
# 5510  adequate handwashing sinks properly supplied a...
# 5509                  certified food protection manager
# ...

# %%
#convert Violations cat to Title Case
facilities_violations['violation_category'] = facilities_violations['violation_category'].str.title()
#And lower cat to capital case
facilities_violations['lower'] = facilities_violations['lower'].str.capitalize()
facilities_violations
# Out:
#      facility_id inspection_date        violation_category  \
# 5511   FA0001782      2019-12-30               Food Source
# 5510   FA0001782      2019-12-30       Toilets/Handwashing
# 5509   FA0001782      2019-12-30                 Personnel
# 5508   FA0001782      2019-12-30     Water/Sewage/Plumbing
# 631    FA0000193      2019-12-26               Food Source
# ...          ...             ...                       ...
# 1205   FA0000356      2013-01-02                 Personnel
# 1204   FA0000356      2013-01-02            Poisons/Toxins
# 4660   FA0001272      2013-01-02                 Personnel
# 4659   FA0001272      2013-01-02     Water/Sewage/Plumbing
# 7153   FA0003410      2013-01-02  Food Temperature Control
#
#                                                   lower
# 5511                Proper date marking and disposition
# 5510  Adequate handwashing sinks properly supplied a...
# 5509                  Certified food protection manager
# ...

# %%
#create the vilations category, contactenate the data, use an underscore to mark the end of one violation and the beginning of another.
facilities_violations['combo'] = facilities_violations['inspection_date']+' - '+facilities_violations['violation_category']+' - '+facilities_violations['lower']+"_"
facilities_violations

# create a simplified DF
facilities_violations_simple = facilities_violations[["facility_id", "combo"]]
facilities_violations_simple
# Out:
#      facility_id                                              combo
# 5511   FA0001782  2019-12-30 - Food Source - Proper date marking...
# 5510   FA0001782  2019-12-30 - Toilets/Handwashing - Adequate ha...
# 5509   FA0001782  2019-12-30 - Personnel - Certified food protec...
# 5508   FA0001782  2019-12-30 - Water/Sewage/Plumbing - Hot & col...
# 631    FA0000193  2019-12-26 - Food Source - Proper date marking...
# ...          ...                                                ...
# 1205   FA0000356          2013-01-02 - Personnel - Training needed_
# 1204   FA0000356     2013-01-02 - Poisons/Toxins - Properly stored_
# 4660   FA0001272       2013-01-02 - Personnel - Hygienic practices_
# 4659   FA0001272  2013-01-02 - Water/Sewage/Plumbing - Hot and c...
# 7153   FA0003410  2013-01-02 - Food Temperature Control - Cold h...
#
# [8730 rows x 2 columns]

# %%
# Combine the data into a single dataset
facilities_json_merged = pd.merge(facilities_json, facilities_violations_simple, how="left", on=["facility_id", "facility_id"])

# Flatten the combo column to a single line
merged_vio = facilities_json_merged.groupby('facility_id')['combo'].apply(''.join).reset_index()
merged_vio
# Out:
#     facility_id                                              combo
# 0     FA0000009  2017-05-09 - Food Source - Cross contamination...
# 1     FA0000010  2017-05-16 - Water/Sewage/Plumbing - Hot and c...
# 2     FA0000011  2015-03-20 - Personnel - Hygienic practices_20...
# 3     FA0000015  2017-10-05 - Personnel - Hygienic practices_20...
# 4     FA0000017  2019-07-30 - Food Source - Consumer advisory p...
# ..          ...                                                ...
# 861   FA0005449  2019-12-12 - Physical Facilities - Adequate ve...
# 862   FA0005472  2019-10-28 - Personnel - Certified food protec...
# 863   FA0005494  2019-10-01 - Personnel - Procedures for respon...
# 864   FA0005506  2019-10-24 - Equipment/Utensil Cleaning - Ware...
# 865   FA0005510  2019-10-14 - Personnel - Certified food protec...
#
# [866 rows x 2 columns]

# %%
#copy the df
facilities_json_vio = facilities_json.copy()

#loop over the violations df to assemble FacID plus facility name plus violations
for index, row in merged_vio.iterrows():
        #find the facID and violation data
        facID = merged_vio.loc[index, "facility_id"]
        violations = merged_vio.loc[index, "combo"]

        #drop the violationdata into the clean dataframe
        facilities_json_vio.loc[(facID == facilities_json["facility_id"]), 'violations'] = violations
              
facilities_json_vio_clean = facilities_json_vio[["facility_name_plus", "violations"]]
facilities_json_vio_clean
# Out:
#                                     facility_name_plus  \
# 160  ALLENSPARK - MEADOW MOUNTAIN CAFE - 441 BUSINE...
# 6    ALLENSPARK - ROCKY MOUNTAIN PATHWAY RANCH - 15...
# 407     BOULDER - (CU)  FARRAND ALLEY - 2200 BARKER DR
# 442       BOULDER - (CU) SEEC CAFE - 4001 DISCOVERY DR
# 408  BOULDER - (CU) SEWALL DINING CENTER - 1720 UNI...
# ..                                                 ...
# 426          SUPERIOR - SUSHI OUTLET - 402 MARSHALL RD
# 427     SUPERIOR - TEQUILA Y MEZCHAL - 1631 COALTON RD
# 90        WARD - GLACIER VIEW RANCH - 8748 OVERLAND RD
# 722        WARD - JACKLEGGERS MERCANTILE - 62 UTICA ST
# 167                 WARD - MILLSITE INN - 44365 HWY 72
#
#                                             violations
# 160  2019-08-29 - Food Source - Consumer advisory p...
# 6       2014-06-18 - Poisons/Toxins - Properly stored_
# 407  2015-02-05 - Water/Sewage/Plumbing - Backflow ...
# 442  2019-12-10 - Food Temperature Control - Proper...
# ...

# %% [markdown]
# # Make the Json Files

# %%
# Export cleaned, dataset for Json conversion A
output_data = "Export/dashboard_facility_data_cities.csv"
facilities_json.to_csv(output_data,header=True,index=False, float_format='%.2f')

# %%
# Export cleaned, dataset for Json conversion B
output_data = "Export/violation_data_dashbaord.csv"
facilities_json_vio_clean.to_csv(output_data,header=True,index=False)

# %%
# function to create json from CSV A
def make_json(csvFilePath, jsonFilePath):

    # create the facility dictionary
    data = {"names" : [], "metadata": []}
    
    # Open a csv reader called DictReader
    with open(csvFilePath, encoding='utf-8') as csvf:
        csvReader = csv.DictReader(csvf)

        # Convert each row for the dictionary
        for rows in csvReader:
            name = rows["facility_name_plus"]
            data["names"].append(name)
            data["metadata"].append(rows)

    # Open a json writer, and use the json.dumps()
    # function to dump data
    with open(jsonFilePath, 'w', encoding='utf-8') as jsonf:
        jsonf.write(json.dumps(data, indent=4))
         
# Driver Code
#Set the file paths
csvFilePath = r'Export/dashboard_facility_data_cities.csv'
jsonFilePath = r'../Website_Files/web_facility_data.json'
 
# Call the make_json function
make_json(csvFilePath, jsonFilePath)

# %%
# function to create json from CSV B
def make_json(csvFilePath, jsonFilePath):

    # create the facility dictionary
    data = {"facility_names_plus" : [], "violations": []}
    
    # Open a csv reader called DictReader
    with open(csvFilePath, encoding='utf-8') as csvf:
        csvReader = csv.DictReader(csvf)

        # Convert each row for the dictionary
        for rows in csvReader:
            name = rows["facility_name_plus"]
            data["facility_names_plus"].append(name)
            data["violations"].append(rows)

    # Open a json writer, and use the json.dumps()
    # function to dump data
    with open(jsonFilePath, 'w', encoding='utf-8') as jsonf:
        jsonf.write(json.dumps(data, indent=4))
         
# Driver Code
#Set the file paths
csvFilePath = r'Export/violation_data_dashbaord.csv'
jsonFilePath = r'../docs/web_facility_data2.json'
 
# Call the make_json function
make_json(csvFilePath, jsonFilePath)
