# %% [markdown]
# # Dependencies & Read Data

# %%
#Imports
import pandas as pd
import requests
import gmaps
import re
import numpy as np

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
#Read the CSV & Create DF
clean_geocoded_df = pd.read_csv("cleaned_facility_data.csv")
clean_geocoded_df.head(1)
# Out:
#   facilityId facilityName                concat_address  \
# 0  FA0003323        RUNZA  1743 MAIN ST LONGMONT CO USA
#
#               typeOfFacility         categoryOfFacility  origin_lat  \
# 0  RESTAURANT 0 TO 100 SEATS  FULL MENU LIMITED SERVICE   40.189746
#
#    origin_long  google_lat  google_long
# 0  -105.102332   40.189772  -105.102667

# %% [markdown]
# # Assemble Places API Call

# %%
#Configure API Call for Nearby Search using enough parameters to ensure we get the right place! 
params = {
    "rankby": "distance",
    "keyword": "restaurant",
    "location": "40.189772, -105.102667",
    "name": "RUNZA",
    "key": g_key
}

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

rest = requests.get(base_url, params=params).json()

rest["results"][0]["price_level"]
# Out:
# 1

# %% [markdown]
# # Make the Call

# %%
params = {
    "rankby": "distance",
    "keyword": "restaurant",
    "key": g_key
}

#iterate through that dataframe!
for index, row in clean_geocoded_df.iterrows():
    try: 
        # Get the Name Address from the dataframe
        name = row["facilityName"]
        lat = row["google_lat"]
        long = row["google_long"]
        params["location"] = f"{lat},{long}"
        params["name"] = name

        # Set the base URL to grab JSON data
        base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

        # Make request and retrieve the JSON data from the search. 
        search = requests.get(base_url, params=params).json()

        #Set Biz status, Name, Rating, price_level, user_ratings_total variables
        g_status = search["results"][0]["business_status"] 
        g_name = search["results"][0]["name"]
        g_rating = search["results"][0]["rating"]
        g_price_level = search["results"][0]["price_level"]
        g_user_ratings = search["results"][0]["user_ratings_total"]

        # Get all fields and store in new columns
        clean_geocoded_df.loc[index, "biz_status"] = g_status
        clean_geocoded_df.loc[index, "gbiz_name"] = g_name
        clean_geocoded_df.loc[index, "rating"] = g_rating
        clean_geocoded_df.loc[index, "price_level"] = g_price_level
        clean_geocoded_df.loc[index, "total_user_ratings"] = g_user_ratings
               
    except (KeyError):
        print(f"{name} not found, skip - Key") 
    except (IndexError):
         print(f"{name} not found, skip - Index") 
clean_geocoded_df.head()
# Out:
# ROASTED TOAD BBQ THE not found, skip - Key
# FAIR ISLE COFFEE CO @ LGMT FARM MRKT not found, skip - Index
# CARNICERIA EL CERRITO not found, skip - Key
# UTE CREEK GOLF COURSE not found, skip - Key
# LEVY IPF 1 (MOBILE) not found, skip - Key
# BOULDER BEEF (MOBILE PRE-PKG) not found, skip - Index
# MOUNTAIN VIEW GRILL 2  (MOBILE) not found, skip - Index
# CUPPA HOUSE COFFEE & TEA not found, skip - Key
# (CU) C4C THE BAKERY not found, skip - Key
# AREPA JOINT THE (MOBILE) not found, skip - Key
# NIWOT WHEEL WORKS not found, skip - Key
# ARAPAHOE MEAT CO not found, skip - Key
# CHOP 5 SALAD KTICHEN not found, skip - Key
# SMOKIN BOWLS not found, skip - Key
# (CU)  FARRAND ALLEY not found, skip - Key
# EGGLOO DELIGHTS (SPECIAL EVENT) not found, skip - Index
# LA PUPUSA LOCA (MOBILE) not found, skip - Key
# LA FAMILIA (MOBILE) not found, skip - Key
# FRASIER MEADOWS MANOR KITCHEN not found, skip - Key
# HOMEWOOD SUITES BOULDER not found, skip - Key
# GREAT OUTDOORS WATER PARK THE not found, skip - Key
# MEEKER PARK LODGE not found, skip - Key
# COMMUNITY CUPBOARD FOOD BANK not found, skip - Key
# ROCK CREEK TAVERN & PIZZERIA not found, skip - Key
# LA BARRA DEL SAZON (MOBILE) not found, skip - Key
# JAMBA JUICE @ UMC (CU) not found, skip - Key
# JUNGLE not found, skip - Key
# FRESH THYMES MARKETPLACE not found, skip - Key
# TRES REYNAS not found, skip - Key
# GABEE COFFEE not found, skip - Key
# RUSTY MELON THE not found, skip - Key
# UBON THAI CUISINE not found, skip - Key
# COLORADO CHAUTAUQUA ASSOCIATION not found, skip - Key
# PASSPORT FOOD TRUCK not found, skip - Key
# VFW POST 1771 not found, skip - Key
# THERE WITH CARE (PANTRY) not found, skip - Key
# PEACEFUL MEADOW  RETREAT not found, skip - Key
# WHEEL & WHISK THE (MOBILE) not found, skip - Key
# CHOCOLATERIE STAM not found, skip - Key
# HISSHO SUSHI #312 (INSIDE SPROUTS) not found, skip - Index
# QUALITY INN not found, skip - Key
# HOLY CREPE (MOBILE) not found, skip - Key
# RUTHIES not found, skip - Key
# A TAKEAR (MOBILE) not found, skip - Key
# BREWING MARKET not found, skip - Key
# ROBIN CHOCOLATES not found, skip - Key
# POLLERIA LA FOGATA not found, skip - Key
# INDIAS GROCERY not found, skip - Key
# RAZA FRESA MEXICAN KITCHEN not found, skip - Key
# (CU) VILLAGE CENTER THE GRANGE (GRILLE) not found, skip - Key
# SISTER CARMEN COMMUNITY CENTER not found, skip - Key
# AIMES LOVE not found, skip - Key
# ASIAN SEAFOOD MARKET not found, skip - Key
# OBSERV LOCATION 2 (MOBILE) not found, skip - Key
# LEVY FOLSOM FIELD HOT PREP KITCHEN 6TH FLOOR (CU) not found, skip - Key
# HAMPTON INN not found, skip - Key
# LEVY FOLSOM FIELD COLD KITCHEN 6TH FLOOR (CU) not found, skip - Index
# INDIAN PEAKS GOLF COURSE AT LAFAYET not found, skip - Key
# JACKLEGGERS MERCANTILE not found, skip - Key
# AOI not found, skip - Key
# TAQUERIA MADERO not found, skip - Key
# ETAIS AT CU not found, skip - Key
# SCROOGE MAKI 1 (MOBILE) not found, skip - Key
# LAS PALMERAS EXPRESS not found, skip - Key
# OZO COFFEE CAFE not found, skip - Key
# TEN PIN ALLEY not found, skip - Key
# PEAK GOLF not found, skip - Key
# BF MOUNTAIN MARKET not found, skip - Key
# HOLIDAY INN EXPRESS QWMCO not found, skip - Key
# LA GARNACHA (MOBILE) not found, skip - Key
# MACS PLACE @GE OIL & GAS not found, skip - Index
# 300 SUNS BREWING not found, skip - Key
# NATURAL GROCERS not found, skip - Key
# RALLY SPORT HEALTH AND FITNESS not found, skip - Key
# SCRATCH KITCHENS not found, skip - Key
# SEVENTEEN THIRTY-NINE not found, skip - Key
# BPOE LODGE 566 not found, skip - Key
# SEEDS LIBRARY CAFE not found, skip - Key
# HARD DRIVE CAFE AT SEAGATE not found, skip - Key
# RAPHA RACING not found, skip - Key
# TRES GRINGOS CANTINA not found, skip - Key
# GIOVANNITTI COFFEE not found, skip - Key
# LEVY MOTIONS (MOBILE) not found, skip - Key
# NITRO CLUB not found, skip - Key
# ETOWN HALL not found, skip - Key
# LE FRENCH CAFE not found, skip - Key
# (CU) SEWALL DINING CENTER not found, skip - Key
# LONCHERA LOS PAISAS (MOBILE) not found, skip - Key
# NATURAL HOMESTEAD BEEF (PRE-PKG MOBILE 2) not found, skip - Index
# HAMPTON INN & SUITES not found, skip - Key
# (CU) UMC FRONT HOUSE ALFERD PACKER not found, skip - Key
# GUACAMOLES not found, skip - Key
# HYATT PLACE BOULDER not found, skip - Key
# GOLD HILL GENERAL STORE AND PUB not found, skip - Key
# MICRO MOTION CAFE not found, skip - Index
# RESIDENCE INN LONGMONT not found, skip - Key
# GOLD'S GYM LONGMONT not found, skip - Key
# CANDLEWOOD SUITES not found, skip - Key
# BECLA (BAKERY INSIDE SAVE A LOT) not found, skip - Index
# HAYSTACK MOUNTAIN GOAT DAIRY not found, skip - Key
# TACO PALACE LONGMONT not found, skip - Key
# TONIC ALCHEMY LOUNGE not found, skip - Key
# COVERED WAGON not found, skip - Key
# HOPI BREAD @ LMGT FARM MRKT (SPECIAL EVENT) not found, skip - Key
# TORTILLERIA LA ESMERALDA(PRE-PKG FMRS MRKT) not found, skip - Index
# REBECCAS HERBAL APOTHECARY & S not found, skip - Key
# AFC SUSHI (INSIDE SAFEWAY #1667) not found, skip - Key
# CENTURY THEATRE not found, skip - Key
# LAS AMERICAS TORTILLERIA not found, skip - Key
# GUCKENHEIMER@ GOOGLE RED ROCKS (2600) not found, skip - Key
# WHOLE FOODS MARKET not found, skip - Key
# DRY STORAGE not found, skip - Key
# LA CHOZA #3 not found, skip - Key
# ABUELITAS EMPANADAS not found, skip - Key
# LONGMONT PACKING 1 CARNICERIA not found, skip - Key
# SAM'S CLUB #4987 not found, skip - Key
# UCAR not found, skip - Key
# HOPI BREAD @ BLDR FARM MRKT (SPECIAL EVENT) not found, skip - Key
# VILLAGE PLACE AT LONGMONT not found, skip - Key
# SUPERIOR LIQUOR not found, skip - Key
# SAVE A LOT not found, skip - Key
# LA RUE BAYOU (MOBILE) not found, skip - Key
# BOULDER INDOOR SOCCER not found, skip - Key
# PANADERY Y NEVERIA GUANAJUATO not found, skip - Index
# STYRIA BAKERY @ LMGT FRM MRKT (SPECIAL EVENT) not found, skip - Key
# SAVORY SAIGON COMISSARY (SPECIAL EVENT) not found, skip - Key
# HAMPTON INN LOUISVILLE not found, skip - Index
# BASECAMP HOTEL not found, skip - Key
# PERSIMMON GRILL AT LAKE VALLEY GOLF not found, skip - Key
# KRISHNA GRANDE not found, skip - Index
# SILVER CANYON COFFEE DRIP BAR @ LMGT FRM MRKT (SPECIAL EVENT) not found, skip - Key
# LAS DELICIAS (INSIDE SAVE-A-LOT) not found, skip - Key
# SAIGON EXPRESS not found, skip - Key
# SPROUTS FARMERS MARKET not found, skip - Key
# KONA ICE OF BOULDER (MOBILE) not found, skip - Index
# ROCKY MOUNTAIN PATHWAY RANCH not found, skip - Key
# AMANTE UPTOWN not found, skip - Key
# BEST WESTERN PLUS not found, skip - Key
# LAUGHING GOAT NORLIN not found, skip - Key
# JFE (KS-102) not found, skip - Index
# CUGINI PIZZERIA not found, skip - Key
# CORNER THE not found, skip - Key
# JFE SNOWFOX KS061 not found, skip - Index
# SPICE EXCHANGE not found, skip - Key
# CASPIAN DELI AND GROCERY not found, skip - Key
# BOULDER CREEK LODGE THE not found, skip - Key
# LA QUINTA INN 952 not found, skip - Index
# KING SOOPERS 80 not found, skip - Key
# WALGREENS #19547 not found, skip - Key
# NORTH BOULDER LIQUOR not found, skip - Key
# SUBWAY 30680 not found, skip - Index
# FANS CHINESE CUISINE not found, skip - Key
# CURED not found, skip - Key
# TEX MEX not found, skip - Key
# HAZELS BEVERAGE WORLD not found, skip - Key
# TORTILLAS Y PANADERIA LAGUNA not found, skip - Key
# FOX HILL COUNTRY CLUB not found, skip - Key
# TWISTED PINE BREWING COMPANY not found, skip - Key
# MOUNTAIN VIEW GRILL (MOBILE) not found, skip - Index
# LOYAL ORDER OF MOOSE LONGMONT LODGE not found, skip - Key
# JAMESTOWN MERCANTILE CAFE not found, skip - Index
# FLIGHT DECK GRILL (MOBILE) not found, skip - Key
# COURTYARD BY MARRIOTT 1067 not found, skip - Key
# CINEBARRE not found, skip - Key
# SPIRIT HOUND DISTILLERS not found, skip - Key
# JOHN HAROLD BUCKLEY POST 32 not found, skip - Key
# TIFFIN WALLAH not found, skip - Index
# LOAF N JUG 95 not found, skip - Key
# HOLIDAY INN EXPRESS not found, skip - Key
# NIWOT MARKET not found, skip - Key
# KING SOOPERS 135 not found, skip - Key
# BOULDER COUNTY JAIL not found, skip - Key
# JFE SUSHI (KS-80) not found, skip - Key
# BOULDER COUNTRY CLUB SNACK BAR not found, skip - Key
# MOUNTAIN PEOPLES COOP not found, skip - Key
# NATURAL GROCERS BY VITAMIN COTTAGE not found, skip - Key
# GREEN BELLY FOODS BLDR (MOBILE PRE-PKG) not found, skip - Index
# RIVERSIDE not found, skip - Key
# BLUE OWL BOOKS not found, skip - Key
# UCAR not found, skip - Key
# ELDORADO CORNER MARKET not found, skip - Key
# SPROUTS FARMERS MARKET not found, skip - Key
# BOULDER SHELTER FOR THE HOMELESS not found, skip - Key
# YOUR BUTCHER FRANK III not found, skip - Key
# DOS WAPOS not found, skip - Key
# COOL BEADS (MOBILE) not found, skip - Index
# JFE SUSHI (KS-013) not found, skip - Key
# WALGREENS #19103 not found, skip - Index
# SENOR GOMEZ not found, skip - Key
# ELDORA MTN RESORT LOOKOUT RESTAURANT not found, skip - Key
# JESTERS PERFORMING ARTS not found, skip - Key
# SUR LA TABLE not found, skip - Key
# AMERICAN LEGION POST 111 not found, skip - Key
# LAS CAZUELAS not found, skip - Key
# WILD BASIN LODGE & EVENT CENTER not found, skip - Index
# GARDEN GATE CAFE THE not found, skip - Key
# RAYBACK COLLECTIVE not found, skip - Key
# NATURAL GROCERS BY VITAMIN COTTAGE not found, skip - Key
# COURTYARD BY MARRIOTT not found, skip - Key
# STARBUCKS 21402 not found, skip - Index
# EUREST DINING SERVICE AT IBM CANTEE not found, skip - Key
# SPRUCE CAFE not found, skip - Key
# NCAR not found, skip - Key
# LONGMONT YOUTH CENTER not found, skip - Key
# CURE ORGANIC FARM (FARMERS MARKET) not found, skip - Key
# COLORADO ATHLETIC CLUB not found, skip - Key
# 7 ELEVEN 41867 not found, skip - Index
# KOREA HOUSE not found, skip - Key
# YURIHANA not found, skip - Key
# BOULDER BURGER not found, skip - Key
# ALL TIME FAVORITES (SPECIAL EVENT) not found, skip - Key
# GOODY MONSTER not found, skip - Key
# TORTILLAS DE LA FRONTERA not found, skip - Key
# WINOT COFFEE not found, skip - Key
# COLORADO ATHLETIC CLUB AT FLATIRONS not found, skip - Key
# BPOE LODGE 1055 not found, skip - Key
# SUNSET GOLF COURSE not found, skip - Key
# LUUS ASIAN CUISINE not found, skip - Key
# LA LOMA CARNICERIA not found, skip - Key
# SCROOGE MAKI not found, skip - Key
# GLACIER VIEW RANCH not found, skip - Key
# SUNRISE BISON RANCH @ BLDR FARM MRKT (PRE-PKG) not found, skip - Index
# OZO EAST PEARL not found, skip - Key
# MCDEVITT TACO SUPPLY not found, skip - Key
# ELDORA MOUNTAIN RESORT not found, skip - Key
# SUPER TARGET 1769 not found, skip - Key
# ASIAN CUISINE AND VIETNAMESE not found, skip - Key
# AMERICAN LEGION BOULDER POST 10 not found, skip - Key
# DAIRY CENTER FOR THE ARTS THE not found, skip - Key
# SHOES AND BREWS not found, skip - Key
# DANNYS TACOS not found, skip - Key
# GOLD HILL INN not found, skip - Key
# COMPASS GROUP USA (QUALCOMM) not found, skip - Index
# BOULDER COMMUNITY FOOTHILLS HOSPITAL not found, skip - Key
# BELEZA COFFEE BAR not found, skip - Key
# NEDERLAND COMMUNITY CENTER not found, skip - Key
# COSMOS PIZZA not found, skip - Key
# RATS WOODSHACK (MOBILE) not found, skip - Key
# MICI not found, skip - Key
# OUR CENTER not found, skip - Key
# RESIDENCE INN BY MARRIOTT LOUISVILLE not found, skip - Index
# EDIBLE ARRANGEMENTS not found, skip - Key
# BLUE REEF SEAFOOD MARKET not found, skip - Key
# KING SOOPERS 13 not found, skip - Key
# MCDEVITT TACO SUPPLY (MOBILE) not found, skip - Key
# AVISTA HOSPITAL not found, skip - Key
# BOULDER PHO & MILK TEA not found, skip - Key
# CANYON CAFE not found, skip - Key
# JEANNOTS PATISSERIE & BISTRO not found, skip - Key
# RAKKAN RAMEN not found, skip - Key
# LOLITAS MARKET & DELI not found, skip - Key
# MEADOW LARK FARM DINNERS (MOBILE) not found, skip - Index
# TACOS GTO not found, skip - Key
# JANUARY COFFEE not found, skip - Key
# NEVERIA LA ZUMBA not found, skip - Key
# LA MOMO MAES BAKERY not found, skip - Key
# CASIAN SEAFOOD not found, skip - Key
# BEST PHO not found, skip - Key
# SEBS PIZZAS (MOBILE) not found, skip - Key
# AREPAS CARIBBEAN FOOD (MOBILE) not found, skip - Index
# IZZIO ARTISAN BAKERY LMGT FARMER MKT not found, skip - Key
# BOSS LADY PIZZA not found, skip - Key
# RUBY RUS not found, skip - Key
# CASA AGAVE not found, skip - Key
# LAUDISIO 2 (MOBILE) not found, skip - Index
# IZOTE LATIN FOOD #3 (MOBILE) not found, skip - Key
# PLACERITA RANCH (PRE-PKG MOBILE)@ BC FMRS MRKT not found, skip - Index
# GRILL AT COAL CREEK THE not found, skip - Key
# CHEESE LOVE GRILL 2 (MOBILE) not found, skip - Index
# GEMINI not found, skip - Key
# SKYPILOT FARM #1 @ FMR MRKT not found, skip - Key
# PASTIFICIO BOULDER @ BLDR FARM MRKT not found, skip - Key
# MONO MONO KFC not found, skip - Key
# BASIL BOWL not found, skip - Key
# WAFFLE LAB THE not found, skip - Key
# SHORTSTOP FAIRVIEW not found, skip - Key
# JUICE BEE THE not found, skip - Key
# GURKHAS DUMPLING AND CURRY HOUSE not found, skip - Key
# TACOS LA FAMILIA #1 (MOBILE) not found, skip - Key
# TIMES COLLABORATIVE THE not found, skip - Key
# GUCKENHEIMER@ GOOGLE (GRAB & GO) not found, skip - Index
# GUCKENHEIMER@ GOOGLE - COUNTER THE not found, skip - Index
# GUCKENHEIMER@ 2600 BARISTA not found, skip - Key
# TIP TOP SAVORY PIES not found, skip - Key
# BIG DADDYS TEXAS BBQ (MOBILE) not found, skip - Key
# TUNE UP AT FULL CYCLE not found, skip - Key
# HAMPTON INN & SUITES not found, skip - Key
# MAINE EVENT THE (MOBILE) not found, skip - Index
# SPRINGHILL SUITES BOULDER LONGMONT not found, skip - Key
# MCCASLIN THAI not found, skip - Key
# ORANGE TENT THE (SPECIAL EVENT) not found, skip - Index
# FAIRWAYS GOLF not found, skip - Key
# PRICKLY PEAR TAVERN, THE not found, skip - Key
# DIZZY FAMILY FUN CENTER (TEMPORARY EVENT) not found, skip - Key
# (CU) LIBBY DINING CENTER not found, skip - Key
# AVANTI F&B COMMISSARY & BARS not found, skip - Key
# MY NEIGHBOR FELIX not found, skip - Key
# BIRDCALL 29TH ST not found, skip - Key
# COFFEE BAR MEDTRONIC BOULDER not found, skip - Key
# SPOTTED JAMES THE not found, skip - Key
# CROSSING NUTRITION THE not found, skip - Key
# HOLY CREPE not found, skip - Key
# SWAYLOS TIKI not found, skip - Key
# R GALLERY not found, skip - Key
# FAROW not found, skip - Key
# DIA Y NOCHE CAFE not found, skip - Key
# GHOST BOX PIZZA not found, skip - Key
# CU ATHLETICS not found, skip - Key
# VIET KITCHEN (AT ATLAS VALLEY) not found, skip - Key
# META BURGER not found, skip - Key
# JFE SUSHI SC4987 (INSIDE SAMS CLUB) not found, skip - Index
# HIGHLAND CITY CLUB not found, skip - Key
# QUARTERS BAR+ARCADE not found, skip - Key
# COSMOS PIZZA not found, skip - Key
# ROSETTA HALL STALL 2 not found, skip - Key
# WYATTS WINES AND SPIRITS not found, skip - Key
# MARRIOTT RESIDENCE INN not found, skip - Key
# NO QUE NO (MOBILE) not found, skip - Key
# CANYON MARKET PLACE not found, skip - Index
# TEOCALLI COCINA not found, skip - Key
# ROSETTA HALL STALL 10 BAR not found, skip - Key
# TORTILLERIA LAS 5 AMERICAS not found, skip - Key
# VEGETABLE EXPRESS THE (MOBILE) not found, skip - Key
# HILTON GARDEN INN - BOULDER not found, skip - Key
# INN BETWEEN THE (PANTRY) not found, skip - Index
# SIMPLY BULK MARKET not found, skip - Key
# FALAFEL KING not found, skip - Key
# SCRATCH (INSIDE 300 SUNS BREWING) not found, skip - Key
# SPRUCE CAFE not found, skip - Key
# LAS X AMERICAS TORTILLERIA Y CARNICERIA not found, skip - Key
# SAVANNAH BEE COMPANY not found, skip - Key
# PHO HUONG VIET not found, skip - Key
# SWEET DOODLES FROYO not found, skip - Key
# LONGS PEAK GROCERY MARKET not found, skip - Key
# AMPERSAND COFFEE ROASTER not found, skip - Key
# CARIBOU ROOM THE not found, skip - Key
# HARVEST OF HOPE PANTRY not found, skip - Key
# BOULDER MARRIOTT not found, skip - Key
# LE FRIGO not found, skip - Key
# PEARL STREET GRILL (COMMISSARY) not found, skip - Key
# COURTYARD LOUISVILLE MARRIOTT not found, skip - Key
# GROWING GARDENS not found, skip - Key
# EMBASSY SUITES BOULDER not found, skip - Key
# COMMUNITY FOOD SHARE not found, skip - Key
# CENTENNIAL PEAKS HOSPITAL not found, skip - Key
# LONGS PEAK HOSPITAL not found, skip - Key
# FRONT RANGE COMMUNITY COLLEGE (PANTRY) not found, skip - Key
# EFAA not found, skip - Key
# TIP TOP SAVORY PIES LLC not found, skip - Key
# MENTAL HEALTH PARTNERS RYAN WELLNESS CENTER not found, skip - Key
# ALTAVITA INDEPENDENT LIVING not found, skip - Key
# BIG LOTS #4685 not found, skip - Key
# BOULDER COUNTY AIDS PROJECT (PANTRY) not found, skip - Key
#   facilityId                          facilityName  \
# 0  FA0003323                                 RUNZA
# 1  FA0000616                     FRANKS CHOP HOUSE
# 2  FA0004494                  ROASTED TOAD BBQ THE
# 3  FA0003893  FAIR ISLE COFFEE CO @ LGMT FARM MRKT
# 4  FA0003472                    TODS ESPRESSO CAFE
#
#                    concat_address                          typeOfFacility  \
# 0    1743 MAIN ST LONGMONT CO USA               RESTAURANT 0 TO 100 SEATS
# 1    921 WALNUT ST BOULDER CO USA          RESTAURANT MORE THAN 200 SEATS
# 2    229 HWY 119 NEDERLAND CO USA               RESTAURANT 0 TO 100 SEATS
# 3  237 COLLYER ST Longmont CO USA                           SPECIAL EVENT
# 4  6558 LOOKOUT RD BOULDER CO USA  LIMITED FOOD SERVICE CONVENIENCE OTHER
#
#           categoryOfFacility  origin_lat  origin_long  google_lat  \
# 0  FULL MENU LIMITED SERVICE   40.189746  -105.102332   40.189772
# 1     FULL SERVICE FULL MENU   40.016235  -105.282759   40.016553
# 2  FULL MENU LIMITED SERVICE         NaN          NaN   39.963180
# 3              SPECIAL EVENT   40.163078  -105.098175   40.163077
# 4     FAST FOOD LIMITED MENU   40.072805  -105.201040   40.072171
#
#    google_long   biz_status            gbiz_name  rating  price_level  \
# 0  -105.102667  OPERATIONAL     Runza Restaurant     4.2          1.0
# 1  -105.282845  OPERATIONAL    Frank’s Chophouse     4.3          3.0
# 2  -105.509594          NaN                  NaN     NaN          NaN
# 3  -105.098557          NaN                  NaN     NaN          NaN
# 4  -105.200873  OPERATIONAL  Tod's Espresso Cafe     4.3          1.0
#
#    total_user_ratings
# 0               210.0
# 1               446.0
# 2                 NaN
# 3                 NaN
# 4               170.0

# %% [markdown]
# # Export Data

# %%
# Export unique address dataset w/ Google Data
output_data = "facility_data_with_ratings.csv"
clean_geocoded_df.to_csv(output_data,header=True,index=False)
