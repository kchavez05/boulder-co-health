# %% [markdown]
# # Dependencies & Read Data

# %%
#Imports
import pandas as pd
import requests
import gmaps
import re
import numpy as np

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
#Read the CSV & Create DF
geocoded_df = pd.read_csv("unique_restaurants_geocoded.csv")
geocoded_df.head()
# Out:
#   facilityId                          facilityName      siteAddress  \
# 0  FA0003323                                 RUNZA     1743 MAIN ST
# 1  FA0000616                     FRANKS CHOP HOUSE    921 WALNUT ST
# 2  FA0004494                  ROASTED TOAD BBQ THE      229 HWY 119
# 3  FA0003893  FAIR ISLE COFFEE CO @ LGMT FARM MRKT   237 COLLYER ST
# 4  FA0003472                    TODS ESPRESSO CAFE  6558 LOOKOUT RD
#
#   streetNumber streetDirection streetName streetType streetUnit       city  \
# 0         1743             NaN       MAIN         ST        NaN   LONGMONT
# 1          921             NaN     WALNUT         ST        NaN    BOULDER
# 2          229             NaN    HWY 119        NaN        NaN  NEDERLAND
# 3          237             NaN    COLLYER         ST        NaN   Longmont
# 4         6558             NaN    LOOKOUT         RD        NaN    BOULDER
#
#   state  ... violationCode                                    violation  \
# 0    CO  ...           01B                   Wholesome Free of Spoilage
# 1    CO  ...           02E                      Smoking Eating Drinking
# 2    CO  ...           02C                       Hands Washed As Needed
# 3    CO  ...           08B                             Properly Labeled
# 4    CO  ...          FC51  Plumbing installed; proper backflow devices
#
#   violationPoints violationType violationStatus inspectionScore  \
# 0               0      Critical              In              27
# 1               0      Critical              In              20
# 2               0      Critical              In              45
# 3               0      Critical              In               5
# 4              10           NaN    Not Observed              10
#
#                                             location  \
# 0  1743 MAIN ST\r\nLONGMONT, CO 80501\r\n(40.1897...
# 1  921 WALNUT ST\r\nBOULDER, CO 80302\r\n(40.0162...
# 2                 229 HWY 119\r\nNEDERLAND, CO 80466
# 3  237 COLLYER ST\r\nLongmont, CO 80501\r\n(40.16...
# 4  6558 LOOKOUT RD\r\nBOULDER, CO 80301\r\n(40.07...
#
#                    concat_address            split_coords  \
# 0    1743 MAIN ST LONGMONT CO USA  40.189746, -105.102332
# 1    921 WALNUT ST BOULDER CO USA  40.016235, -105.282759
# 2    229 HWY 119 NEDERLAND CO USA                     NaN
# 3  237 COLLYER ST Longmont CO USA  40.163078, -105.098175
# 4  6558 LOOKOUT RD BOULDER CO USA   40.072805, -105.20104
#
#              google_coords
# 0  40.1897717,-105.1026674
# 1  40.0165533,-105.2828453
# 2  39.9631805,-105.5095941
# 3  40.1630767,-105.0985565
# 4  40.0721707,-105.2008731
#
# [5 rows x 25 columns]

# %% [markdown]
# # Data Sort/Clean

# %%
#Drop unnecessary Columns
clean_geocoded = geocoded_df[["facilityId", "facilityName", "concat_address","typeOfFacility", "categoryOfFacility","split_coords","google_coords"]].copy()
clean_geocoded.head()
# Out:
#   facilityId                          facilityName  \
# 0  FA0003323                                 RUNZA
# 1  FA0000616                     FRANKS CHOP HOUSE
# 2  FA0004494                  ROASTED TOAD BBQ THE
# 3  FA0003893  FAIR ISLE COFFEE CO @ LGMT FARM MRKT
# 4  FA0003472                    TODS ESPRESSO CAFE
#
#                    concat_address                          typeOfFacility  \
# 0    1743 MAIN ST LONGMONT CO USA               RESTAURANT 0 TO 100 SEATS
# 1    921 WALNUT ST BOULDER CO USA          RESTAURANT MORE THAN 200 SEATS
# 2    229 HWY 119 NEDERLAND CO USA               RESTAURANT 0 TO 100 SEATS
# 3  237 COLLYER ST Longmont CO USA                           SPECIAL EVENT
# 4  6558 LOOKOUT RD BOULDER CO USA  LIMITED FOOD SERVICE CONVENIENCE OTHER
#
#           categoryOfFacility            split_coords            google_coords
# 0  FULL MENU LIMITED SERVICE  40.189746, -105.102332  40.1897717,-105.1026674
# 1     FULL SERVICE FULL MENU  40.016235, -105.282759  40.0165533,-105.2828453
# 2  FULL MENU LIMITED SERVICE                     NaN  39.9631805,-105.5095941
# 3              SPECIAL EVENT  40.163078, -105.098175  40.1630767,-105.0985565
# 4     FAST FOOD LIMITED MENU   40.072805, -105.20104  40.0721707,-105.2008731

# %% [markdown]
# # Splitting Lat/Long from Original Dataset

# %%
#split lat/long from original dataset into two columns
for index, row in clean_geocoded.iterrows():
    try: 
        #split the data in the location column
        messy = clean_geocoded.loc[index, "split_coords"]
        lat = messy.split(',')[0]   
        long = messy.split(',')[1]

        #drop the lat into its own cell
        clean_geocoded.loc[index, "origin_lat"] = lat
        clean_geocoded.loc[index, "origin_long"] = long
        
    except (AttributeError):
        continue
        
clean_geocoded.head()
# Out:
#   facilityId                          facilityName  \
# 0  FA0003323                                 RUNZA
# 1  FA0000616                     FRANKS CHOP HOUSE
# 2  FA0004494                  ROASTED TOAD BBQ THE
# 3  FA0003893  FAIR ISLE COFFEE CO @ LGMT FARM MRKT
# 4  FA0003472                    TODS ESPRESSO CAFE
#
#                    concat_address                          typeOfFacility  \
# 0    1743 MAIN ST LONGMONT CO USA               RESTAURANT 0 TO 100 SEATS
# 1    921 WALNUT ST BOULDER CO USA          RESTAURANT MORE THAN 200 SEATS
# 2    229 HWY 119 NEDERLAND CO USA               RESTAURANT 0 TO 100 SEATS
# 3  237 COLLYER ST Longmont CO USA                           SPECIAL EVENT
# 4  6558 LOOKOUT RD BOULDER CO USA  LIMITED FOOD SERVICE CONVENIENCE OTHER
#
#           categoryOfFacility            split_coords            google_coords  \
# 0  FULL MENU LIMITED SERVICE  40.189746, -105.102332  40.1897717,-105.1026674
# 1     FULL SERVICE FULL MENU  40.016235, -105.282759  40.0165533,-105.2828453
# 2  FULL MENU LIMITED SERVICE                     NaN  39.9631805,-105.5095941
# 3              SPECIAL EVENT  40.163078, -105.098175  40.1630767,-105.0985565
# 4     FAST FOOD LIMITED MENU   40.072805, -105.20104  40.0721707,-105.2008731
#
#   origin_lat   origin_long
# 0  40.189746   -105.102332
# 1  40.016235   -105.282759
# 2        NaN           NaN
# 3  40.163078   -105.098175
# 4  40.072805    -105.20104

# %% [markdown]
# # Splitting Lat/Long from Google Dataset

# %%
#split lat/long from Geoogle Geocoding dataset into two columns
for index, row in clean_geocoded.iterrows():
    try: 
        #split the data in the location column
        messy = clean_geocoded.loc[index, "google_coords"]
        lat = messy.split(',')[0]   
        long = messy.split(',')[1]

        #drop the lat into its own cell
        clean_geocoded.loc[index, "google_lat"] = lat
        clean_geocoded.loc[index, "google_long"] = long
        
    except (AttributeError):
        continue
        
clean_geocoded.head()
# Out:
#   facilityId                          facilityName  \
# 0  FA0003323                                 RUNZA
# 1  FA0000616                     FRANKS CHOP HOUSE
# 2  FA0004494                  ROASTED TOAD BBQ THE
# 3  FA0003893  FAIR ISLE COFFEE CO @ LGMT FARM MRKT
# 4  FA0003472                    TODS ESPRESSO CAFE
#
#                    concat_address                          typeOfFacility  \
# 0    1743 MAIN ST LONGMONT CO USA               RESTAURANT 0 TO 100 SEATS
# 1    921 WALNUT ST BOULDER CO USA          RESTAURANT MORE THAN 200 SEATS
# 2    229 HWY 119 NEDERLAND CO USA               RESTAURANT 0 TO 100 SEATS
# 3  237 COLLYER ST Longmont CO USA                           SPECIAL EVENT
# 4  6558 LOOKOUT RD BOULDER CO USA  LIMITED FOOD SERVICE CONVENIENCE OTHER
#
#           categoryOfFacility            split_coords            google_coords  \
# 0  FULL MENU LIMITED SERVICE  40.189746, -105.102332  40.1897717,-105.1026674
# 1     FULL SERVICE FULL MENU  40.016235, -105.282759  40.0165533,-105.2828453
# 2  FULL MENU LIMITED SERVICE                     NaN  39.9631805,-105.5095941
# 3              SPECIAL EVENT  40.163078, -105.098175  40.1630767,-105.0985565
# 4     FAST FOOD LIMITED MENU   40.072805, -105.20104  40.0721707,-105.2008731
#
#   origin_lat   origin_long  google_lat   google_long
# 0  40.189746   -105.102332  40.1897717  -105.1026674
# 1  40.016235   -105.282759  40.0165533  -105.2828453
# 2        NaN           NaN  39.9631805  -105.5095941
# 3  40.163078   -105.098175  40.1630767  -105.0985565
# 4  40.072805    -105.20104  40.0721707  -105.2008731

# %% [markdown]
# # Drop combined coord columns

# %%
clean_geocoded.drop(['split_coords','google_coords'], inplace=True,axis=1)
clean_geocoded.head()
# Out:
#   facilityId                          facilityName  \
# 0  FA0003323                                 RUNZA
# 1  FA0000616                     FRANKS CHOP HOUSE
# 2  FA0004494                  ROASTED TOAD BBQ THE
# 3  FA0003893  FAIR ISLE COFFEE CO @ LGMT FARM MRKT
# 4  FA0003472                    TODS ESPRESSO CAFE
#
#                    concat_address                          typeOfFacility  \
# 0    1743 MAIN ST LONGMONT CO USA               RESTAURANT 0 TO 100 SEATS
# 1    921 WALNUT ST BOULDER CO USA          RESTAURANT MORE THAN 200 SEATS
# 2    229 HWY 119 NEDERLAND CO USA               RESTAURANT 0 TO 100 SEATS
# 3  237 COLLYER ST Longmont CO USA                           SPECIAL EVENT
# 4  6558 LOOKOUT RD BOULDER CO USA  LIMITED FOOD SERVICE CONVENIENCE OTHER
#
#           categoryOfFacility origin_lat   origin_long  google_lat  \
# 0  FULL MENU LIMITED SERVICE  40.189746   -105.102332  40.1897717
# 1     FULL SERVICE FULL MENU  40.016235   -105.282759  40.0165533
# 2  FULL MENU LIMITED SERVICE        NaN           NaN  39.9631805
# 3              SPECIAL EVENT  40.163078   -105.098175  40.1630767
# 4     FAST FOOD LIMITED MENU  40.072805    -105.20104  40.0721707
#
#     google_long
# 0  -105.1026674
# 1  -105.2828453
# 2  -105.5095941
# 3  -105.0985565
# 4  -105.2008731

# %% [markdown]
# # Export cleaned facility data

# %%
# Export unique address dataset
output_data = "cleaned_faciliy_data.csv"
clean_geocoded.to_csv(output_data,header=True,index=False)
